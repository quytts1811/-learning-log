# %% [markdown]
# ### Definition of the Derivative
# In Calculus 1, the derivative measures the instantaneous rate of change. The formal definition using limits is:
#
# $$
# f'(x) = \lim_{h \to 0} \frac{f(x+h) - f(x)}{h}
# $$
