# %%
x = float(input("Enter a floating-point number: "))
y = float(input("Enter another floating-point number: "))

z = round(x/y, 2)
print(f"{z:.2f}")
# Out:
# 0.67

# %%
#using function

def hello(sus):
    sus = input("Enter your name: ")
    print("Hello " + sus)

def main():
    hello("sus")

main()

#scope: a variable defined inside a function is not accessible outside the function (local scope)
# Out:
# Hello sibidi

# %%
#Caculator.py
def main():
    x = int(input("Enter first number: "))
    y = int(input("Enter second number: "))
    print (f"x squared is {square(x)}")

def square(n):
    return n ** 2

main()
# Out:
# x squared is 6084

# %%
#conditional statements

def main():
    #>=, <=, ==, !=

    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))

    if x < y:
        print("x is less than y")
    #elif and if are different: elif is only checked if the previous if statement is false while if is always checked
    elif x == y:
        print("x is equal to y")
    else:
        print("x is greater than y")

main()
# Out:
# x is less than y
